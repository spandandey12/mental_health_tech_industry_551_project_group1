# %% [markdown]
# ## Peer Evaluation Submission
#
# ### Group 9 — Bird Distribution
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | The presentation was generally clear, though the storyline could be strengthened with more distinctive insights. | 6 |
# | Delivery criteria (voice, pacing, presence)                         | Delivery was steady, though more engagement with the audience would improve impact. | 6 |
# | Clarity of the visualizations                                       | Visualizations were understandable but could benefit from improved styling and emphasis. | 6 |
# | Quality of the dashboard and visualizations                         | The dashboard was functional, though additional refinement would enhance overall quality. | 6 |
#
# ---
#
# ### Group 2 — Healthcare Survey Analysis
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | The structure was clear, though the presentation relied somewhat on notes. | 7     |
# | Delivery criteria (voice, pacing, presence)                         | Delivery was understandable, though confidence during Q&A could be improved. | 7     |
# | Clarity of the visualizations                                       | Visualizations were clear and reasonably well-organized.                 | 7     |
# | Quality of the dashboard and visualizations                         | The dashboard was solid and usable, with room for further polish.        | 7     |
#
# ---
#
# ### Group 6
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | Despite some unexpected issues, the main ideas were communicated.        | 9     |
# | Delivery criteria (voice, pacing, presence)                         | Delivery was affected slightly by the situation but remained acceptable. | 9     |
# | Clarity of the visualizations                                       | Visual clarity could be improved with more structured presentation support. | 9     |
# | Quality of the dashboard and visualizations                         | UI design was basic but demonstrated core functionality.                 | 9     |
#
# ---
#
# ### Group 3
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | Well-structured and easy to follow.                                      | 8 |
# | Delivery criteria (voice, pacing, presence)                         | Confident and smooth delivery.                                           | 8 |
# | Clarity of the visualizations                                       | Visualizations were clear and effectively supported the narrative.       | 8 |
# | Quality of the dashboard and visualizations                         | Dashboard was well-designed and user-friendly.                           | 8 |
#
# ---
#
# ### Group 12
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | Exceptionally well-structured with a strong narrative flow.              | 10 |
# | Delivery criteria (voice, pacing, presence)                         | Highly polished and engaging delivery.                                   | 10 |
# | Clarity of the visualizations                                       | Visualizations were clear, insightful, and professionally presented.     | 10 |
# | Quality of the dashboard and visualizations                         | Outstanding dashboard with excellent usability and design.               | 10 |
#
# ---
#
# ### Group 8
#
# | Criteria                                                            | Feedback                                                                 | Grade |
# |---------------------------------------------------------------------|--------------------------------------------------------------------------|-------|
# | Clarity of the presentation, organization, and narrative coherence  | Very clear and logically organized presentation.                         | 10 |
# | Delivery criteria (voice, pacing, presence)                         | Confident and well-paced delivery.                                       | 10 |
# | Clarity of the visualizations                                       | Visualizations were clean, clear, and easy to interpret.                 | 10 |
# | Quality of the dashboard and visualizations                         | High-quality dashboard with strong design and usability.                 | 10 |
