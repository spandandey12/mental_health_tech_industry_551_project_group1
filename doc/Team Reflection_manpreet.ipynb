# %% [markdown]
# # Team Project Reflection (Manpreet Singh)
#
# ## 1. Preparation
#
# | Group member name | Preparation rating |
# |-------------------|--------------------|
# | Chongwen Sun      | 4                  |
# | Manpreet Singh    | 4                  |
# | Spandan Dey       | 4                  |
#
# ---
#
# ## 2. Participation & communication
#
# | Group member name | Participation & communication rating |
# |-------------------|--------------------------------------|
# | Chongwen Sun      | 4                                    |
# | Manpreet Singh    | 4                                    |
# | Spandan Dey       | 4                                    |
#
# ---
#
# ## 3. Helps group excel
#
# | Group member name | Helps group excel rating |
# |-------------------|--------------------------|
# | Chongwen Sun      | 4                        |
# | Manpreet Singh    | 4                        |
# | Spandan Dey       | 4                        |
#
# ---
#
# ## 4. Team player (cooperation)
#
# | Group member name | Team player (cooperation) rating |
# |-------------------|----------------------------------|
# | Chongwen Sun      | 4                                |
# | Manpreet Singh    | 4                                |
# | Spandan Dey       | 4                                |
#
# ---
#
# ## Contributions and Reflection
#
# ### How the team worked together
#
# Our team worked collaboratively throughout the project. We maintained communication through regular discussions and divided tasks to ensure steady progress. Team members supported each other and contributed to completing the dashboard on time.
#
# ---
#
# ### My role in the group
#
# I participated in team discussions and contributed to different parts of the project development. I supported the overall progress of the project by helping with assigned tasks and collaborating with teammates when needed.
#
# ---
#
# ### Roles of other team members
#
# **Chongwen Sun** played a key role in leading the development of the dashboard, including data processing, visualization design, and overall coordination. He ensured that the project stayed on track and met the assignment requirements.
#
# **Spandan Dey** contributed to data preparation and integration, and also supported testing and improving the usability of the dashboard.
#
# ---
#
# ### What went well
#
# - The team communicated effectively throughout the project
# - Tasks were distributed to maintain consistent progress
# - The dashboard was completed and submitted on time
# - Team members supported each other during development
#
# ---
#
# ### What could be improved
#
# - More detailed planning at earlier stages of the project
# - Additional refinement of features before final submission
# - Stronger alignment with all assignment requirements during final preparation
